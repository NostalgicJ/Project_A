# %%
import requests
import xml.etree.ElementTree as ET
import json
import math
import time
import sys

# 1. 발급받은 API 키를 여기에 입력하세요
service_key = "50hjvXuloV4qFNdrIUOglZZ6RGV7uq7pvpP0oxT+EV57bvEGnWfvqbjL939z/yfj9ta/H2Cn382mGmHpm4wmcw=="
url = "http://apis.data.go.kr/1471000/CsmtcsIngdCpntInfoService01/getCsmtcsIngdCpntInfoService01"
# 한 번의 호출로 최대한 많은 데이터를 가져오도록 설정
ROWS_PER_PAGE = 1000 
OUTPUT_FILENAME = "korea_standard_ingredients_api.json"

def fetch_all_ingredients():
    """공공 API를 반복 호출하여 전체 성분 데이터를 가져오고 파일로 저장합니다."""
    
    all_ingredients = []
    
    # 1. totalCount (총 데이터 건수) 확인 요청
    print("API 총 데이터 건수를 확인합니다...")
    params = {"serviceKey": service_key, "pageNo": 1, "numOfRows": 1}
    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        root = ET.fromstring(response.content)
        total_count_tag = root.find('.//totalCount')
        
        if total_count_tag is None:
            print("❌ totalCount 정보를 찾을 수 없습니다. API 응답 형식 확인이 필요합니다.")
            return
            
        total_count = int(total_count_tag.text)
        total_pages = math.ceil(total_count / ROWS_PER_PAGE)
        
        print(f"✅ 총 {total_count}개의 성분 정보가 확인되었습니다. 총 {total_pages} 페이지를 호출합니다.")
        
    except Exception as e:
        print(f"❌ 초기 API 요청 중 오류 발생: {e}", file=sys.stderr)
        return

    # 2. 전체 페이지를 순회하며 데이터 수집
    for page_no in range(1, total_pages + 1):
        print(f"➡️ 데이터 수집 중: Page {page_no} / {total_pages}")
        
        params = {
            "serviceKey": service_key, 
            "pageNo": page_no, 
            "numOfRows": ROWS_PER_PAGE
        }
        
        try:
            response = requests.get(url, params=params, timeout=20)
            response.raise_for_status()
            root = ET.fromstring(response.content)
            
            items = root.findall('.//item')
            
            for item in items:
                # 필요한 필드 추출
                ingr_kor_name = item.find('INGR_KOR_NAME').text if item.find('INGR_KOR_NAME') is not None else None
                ingr_eng_name = item.find('INGR_ENG_NAME').text if item.find('INGR_ENG_NAME') is not None else None
                cas_no = item.find('CAS_NO').text if item.find('CAS_NO') is not None else None
                
                # 유효한 한글 성분명이 있는 경우에만 저장
                if ingr_kor_name:
                    all_ingredients.append({
                        "원료명": ingr_kor_name,
                        "영문명": ingr_eng_name,
                        "CAS_NO": cas_no
                    })
                    
            # API 호출 간 부하 방지 및 안정성 확보를 위해 잠시 대기
            time.sleep(0.5) 

        except Exception as e:
            print(f"❌ Page {page_no} 처리 중 오류 발생: {e}", file=sys.stderr)
            time.sleep(5) # 오류 발생 시 더 오래 대기 후 재시도 (혹은 다음 페이지로)
            continue
            
    # 3. 수집된 데이터를 JSON 파일로 저장
    if all_ingredients:
        with open(OUTPUT_FILENAME, 'w', encoding='utf-8') as f:
            json.dump(all_ingredients, f, ensure_ascii=False, indent=4)
        
        print(f"\n🎉 전체 성분 데이터 수집 및 저장 완료!")
        print(f"📦 총 {len(all_ingredients)}개의 성분이 '{OUTPUT_FILENAME}'에 저장되었습니다.")
        
        # 성분 정제에 사용할 표준 한글 성분명 리스트 반환
        return [item['원료명'] for item in all_ingredients]
    else:
        print("❌ 수집된 성분 데이터가 없습니다.")
        return []

# 함수 실행 및 표준 성분 리스트 얻기
standard_ingredients_list = fetch_all_ingredients()
# Out:
# API 총 데이터 건수를 확인합니다...
# ❌ 초기 API 요청 중 오류 발생: 500 Server Error: Internal Server Error for url: http://apis.data.go.kr/1471000/CsmtcsIngdCpntInfoService01/getCsmtcsIngdCpntInfoService01?serviceKey=50hjvXuloV4qFNdrIUOglZZ6RGV7uq7pvpP0oxT%2BEV57bvEGnWfvqbjL939z%2Fyfj9ta%2FH2Cn382mGmHpm4wmcw%3D%3D&pageNo=1&numOfRows=1

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote

# ----------------------------------------------------------------------
# 1단계: 모든 상세 URL 수집 함수
# ----------------------------------------------------------------------
def scrape_all_ingredient_urls(driver, max_page=1288):
    """
    페이지네이션을 이용하여 모든 성분 상세 페이지의 URL을 수집합니다.
    """
    BASE_URL = "https://coos.kr"
    all_detail_urls = set()
    
    # ⚠️ 실제 전체 스크래핑 시에는 max_page=1288로 설정해야 합니다.
    # 테스트를 위해 작은 값으로 설정합니다.
    # max_page = 3  # 테스트용
    
    print(f"==================================================")
    print(f"🔎 1단계: 총 {max_page} 페이지를 탐색하여 성분 URL을 수집합니다...")
    print(f"==================================================")
    
    for page_num in range(1, max_page + 1):
        list_url = f"{BASE_URL}/ingredients?page={page_num}"
        
        try:
            driver.get(list_url)
            time.sleep(1.5) # 로딩 대기 시간 (환경에 따라 조정 필요)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            
            # 성분 상세 URL은 '/ingredients/'로 시작하고 Query String(?)이 없는 <a> 태그의 href를 이용합니다.
            link_tags = soup.find_all(
                'a', 
                href=lambda href: href and href.startswith('/ingredients/') and '?' not in href
            )
            
            # 수집 및 중복 제거
            for tag in link_tags:
                url_path = tag['href']
                full_url = urljoin(BASE_URL, url_path)
                all_detail_urls.add(full_url)
            
            if page_num % 100 == 0 or page_num == 1 or page_num == max_page:
                print(f"   탐색 중: Page {page_num} / {max_page} | 현재 URL 수: {len(all_detail_urls)}개")

        except Exception as e:
            print(f"⚠️ Page {page_num} 로딩 중 오류 발생 ({e}). 건너뛰고 다음 페이지로 이동합니다.")
            continue
            
    print(f"✅ 1단계 완료: 총 {len(all_detail_urls)}개의 성분 상세 URL 수집 완료.")
    return list(all_detail_urls)

# ----------------------------------------------------------------------
# 2단계: 상세 페이지 정보 추출 함수
# ----------------------------------------------------------------------
def scrape_ingredient_details(driver, ingredient_url):
    """
    성분 상세 페이지에서 한글명, 영문명, CAS No.를 안정적으로 추출합니다.
    (동적 CSS 클래스 대신, 태그와 텍스트 레이블 기반)
    """
    driver.get(ingredient_url)
    time.sleep(1) # 로딩 대기
    
    details = {
        '원료명': unquote(ingredient_url.split('/')[-1]), # URL에서 임시로 이름 추출
        '영문명': None,
        'CAS_No': None,
        '설명_요약': None,
        '태그_목록': []
    }
    
    try:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        # 1. 원료명 (한글) 추출: <h1> 태그 사용
        h1_tag = soup.find('h1')
        if h1_tag:
            details['원료명'] = h1_tag.text.strip()
            
            # 2. 영문명 추출: <h1> 태그 내부에 작은 div로 분리되어 있는 경우
            # <div style="...;">...</div> 형태를 찾습니다.
            english_name_div = h1_tag.find_next_sibling('div', style=lambda s: s and 'font-size' in s)
            if english_name_div:
                 details['영문명'] = english_name_div.text.strip()
                 
        # 3. CAS No. 및 상세 정보 추출: <dt> (레이블) / <dd> (값) 쌍 검색
        info_items = soup.find_all(['dt', 'dd'])
        for i in range(len(info_items) - 1):
            if info_items[i].name == 'dt':
                label = info_items[i].text.strip()
                value_tag = info_items[i+1]
                value = value_tag.text.strip() if value_tag and value_tag.name == 'dd' else None
                
                if value and value.lower() != 'none':
                    if 'INCI Name' in label:
                        # 이미 1번에서 추출했으나, 다시 확인하는 용도
                        if not details['영문명']:
                            details['영문명'] = value
                    elif 'CAS No' in label:
                        details['CAS_No'] = value

        # 4. 설명 요약 추출: 페이지 내 특정 CSS 클래스를 가진 div에서 추출 (이전 분석 참고)
        # 클래스가 변경될 수 있으므로, 내용이 긴 첫 번째 단락을 찾는 것도 대안
        summary_div = soup.find('div', class_=lambda c: c and 'css-m3enaf' in c)
        if summary_div:
            details['설명_요약'] = summary_div.text.strip()
            
        # 5. 태그/칩 목록 추출: 모든 칩 레이블 텍스트 수집
        chip_labels = soup.find_all('span', class_=lambda c: c and 'MuiChip-label' in c)
        details['태그_목록'] = [label.text.strip() for label in chip_labels if label.text.strip()]
        
    except Exception as e:
        print(f"   오류 발생: {ingredient_url} 상세 정보 추출 실패: {e}")
        
    return details

# ----------------------------------------------------------------------
# 메인 실행 블록
# ----------------------------------------------------------------------
if __name__ == "__main__":
    # --- 설정 ---
    # ⚠️ (필수) max_page 값을 '1288'로 설정해야 모든 페이지를 스크래핑합니다.
    MAX_PAGE = 3 # 테스트 실행을 위해 3페이지로 설정합니다.
    OUTPUT_FILENAME = "coos_ingredient_database.csv"
    
    # 1. 웹 드라이버 설정 (Selenium Manager가 자동으로 드라이버를 찾아 사용합니다.)
    print("🚀 웹 드라이버 초기화 중...")
    try:
        driver = webdriver.Chrome()
    except Exception as e:
        print(f"❌ 드라이버 초기화 실패. Chrome 설치 및 Selenium 버전 확인이 필요합니다: {e}")
        exit()
        
    start_time = time.time()
    
    # 2. 1단계 실행: 모든 상세 URL 수집
    all_urls = scrape_all_ingredient_urls(driver, max_page=MAX_PAGE)
    
    # 3. 2단계 실행: 상세 정보 추출
    print(f"\n==================================================")
    print(f"🔬 2단계: 수집된 {len(all_urls)}개의 URL에서 상세 정보를 추출합니다...")
    print(f"==================================================")
    
    final_data = []
    
    for i, url in enumerate(all_urls):
        data = scrape_ingredient_details(driver, url)
        data['상세_URL'] = url
        final_data.append(data)
        
        if (i + 1) % 5 == 0 or (i + 1) == len(all_urls):
            print(f"   진행 상황: {i + 1} / {len(all_urls)} ({((i + 1) / len(all_urls) * 100):.1f}%) 추출 완료")

    # 4. 드라이버 종료
    driver.quit()
    
    end_time = time.time()
    
    # 5. 데이터 저장 및 정리
    df = pd.DataFrame(final_data)
    
    # 리스트 형태의 태그 목록을 문자열로 변환하여 CSV에 저장하기 용이하게 합니다.
    df['태그_목록'] = df['태그_목록'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
    
    df.to_csv(OUTPUT_FILENAME, index=False, encoding='utf-8-sig')
    
    print(f"\n==================================================")
    print(f"🎉 작업 완료!")
    print(f"총 소요 시간: {end_time - start_time:.2f}초")
    print(f"최종 데이터 파일: {OUTPUT_FILENAME}")
    print(f"총 {len(df)}개 성분 저장 완료.")
    print(f"==================================================")
# Out:
# 🚀 웹 드라이버 초기화 중...
# ==================================================
# 🔎 1단계: 총 3 페이지를 탐색하여 성분 URL을 수집합니다...
# ==================================================
#    탐색 중: Page 1 / 3 | 현재 URL 수: 20개
#    탐색 중: Page 3 / 3 | 현재 URL 수: 60개
# ✅ 1단계 완료: 총 60개의 성분 상세 URL 수집 완료.
#
# ==================================================
# 🔬 2단계: 수집된 60개의 URL에서 상세 정보를 추출합니다...
# ==================================================
#    진행 상황: 5 / 60 (8.3%) 추출 완료
#    진행 상황: 10 / 60 (16.7%) 추출 완료
#    진행 상황: 15 / 60 (25.0%) 추출 완료
#    진행 상황: 20 / 60 (33.3%) 추출 완료
#    진행 상황: 25 / 60 (41.7%) 추출 완료
#    진행 상황: 30 / 60 (50.0%) 추출 완료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 152
#     149 final_data = []
#     151 for i, url in enumerate(all_urls):
# --> 152     data = scrape_ingredient_details(driver, url)
#     153     data['상세_URL'] = url
#     154     final_data.append(data)
#
# Cell In[3], line 67, in scrape_ingredient_details(driver, ingredient_url)
#      62 """
#      63 성분 상세 페이지에서 한글명, 영문명, CAS No.를 안정적으로 추출합니다.
#      64 (동적 CSS 클래스 대신, 태그와 텍스트 레이블 기반)
#      65 """
#      66 driver.get(ingredient_url)
# ---> 67 time.sleep(1) # 로딩 대기
#      69 details = {
#      70     '원료명': unquote(ingredient_url.split('/')[-1]), # URL에서 임시로 이름 추출
#      71     '영문명': None,
#    (...)
#      74     '태그_목록': []
#      75 }
#      77 try:
#
# KeyboardInterrupt:

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote

# ----------------------------------------------------------------------
# 1단계: 모든 상세 URL 수집 함수
# ----------------------------------------------------------------------
def scrape_all_ingredient_urls(driver, max_page):
    """
    페이지네이션을 이용하여 모든 성분 상세 페이지의 URL을 수집합니다.
    """
    BASE_URL = "https://coos.kr"
    all_detail_urls = set()
    
    print(f"==================================================")
    print(f"🔎 1단계: 총 {max_page} 페이지를 탐색하여 성분 URL을 수집합니다...")
    print(f"==================================================")
    
    for page_num in range(1, max_page + 1):
        list_url = f"{BASE_URL}/ingredients?page={page_num}"
        
        try:
            driver.get(list_url)
            # 로딩 대기 시간: 환경에 따라 조정이 필요하며, 너무 짧으면 데이터 누락, 너무 길면 시간 낭비
            time.sleep(1.5) 
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            
            # 성분 상세 URL은 '/ingredients/'로 시작하고 Query String(?)이 없는 <a> 태그의 href를 이용
            link_tags = soup.find_all(
                'a', 
                href=lambda href: href and href.startswith('/ingredients/') and '?' not in href
            )
            
            # 수집 및 중복 제거
            for tag in link_tags:
                url_path = tag['href']
                full_url = urljoin(BASE_URL, url_path)
                all_detail_urls.add(full_url)
            
            if page_num % 100 == 0 or page_num == 1 or page_num == max_page:
                print(f"   탐색 중: Page {page_num} / {max_page} | 현재 URL 수: {len(all_detail_urls)}개")

        except Exception as e:
            print(f"⚠️ Page {page_num} 로딩 중 오류 발생 ({e}). 건너뛰고 다음 페이지로 이동합니다.")
            # 오류가 나도 프로그램을 멈추지 않고 다음 페이지로 계속 진행
            continue
            
    print(f"✅ 1단계 완료: 총 {len(all_detail_urls)}개의 성분 상세 URL 수집 완료.")
    return list(all_detail_urls)

# ----------------------------------------------------------------------
# 2단계: 상세 페이지 정보 추출 함수 (태그 노이즈 필터링 적용)
# ----------------------------------------------------------------------
def scrape_ingredient_details(driver, ingredient_url):
    """
    성분 상세 페이지에서 한글명, 영문명, CAS No. 및 태그 정보를 추출합니다.
    (태그 목록에서 불필요한 노이즈 코드 제거 로직 포함)
    """
    driver.get(ingredient_url)
    time.sleep(1) # 로딩 대기
    
    details = {
        '원료명': unquote(ingredient_url.split('/')[-1]), 
        '영문명': None,
        'CAS_No': None,
        '설명_요약': None,
        '태그_목록': []
    }
    
    try:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        # 1. 원료명 (한글) 추출: <h1> 태그
        h1_tag = soup.find('h1')
        if h1_tag:
            details['원료명'] = h1_tag.text.strip()
            
            # 2. 영문명 추출: <h1> 바로 다음의 div
            english_name_div = h1_tag.find_next_sibling('div', style=lambda s: s and 'font-size' in s)
            if english_name_div:
                 details['영문명'] = english_name_div.text.strip()
                 
        # 3. CAS No. 및 상세 정보 추출: <dt> (레이블) / <dd> (값) 쌍 검색
        info_items = soup.find_all(['dt', 'dd'])
        for i in range(len(info_items) - 1):
            if info_items[i].name == 'dt':
                label = info_items[i].text.strip()
                value_tag = info_items[i+1]
                value = value_tag.text.strip() if value_tag and value_tag.name == 'dd' else None
                
                if value and value.lower() != 'none':
                    if 'INCI Name' in label and not details['영문명']:
                        details['영문명'] = value
                    elif 'CAS No' in label:
                        details['CAS_No'] = value

        # 4. 설명 요약 추출: CSS 클래스 기반
        summary_div = soup.find('div', class_=lambda c: c and 'css-m3enaf' in c)
        if summary_div:
            details['설명_요약'] = summary_div.text.strip()
            
        # 5. 태그/칩 목록 추출 및 필터링
        chip_labels = soup.find_all('span', class_=lambda c: c and 'MuiChip-label' in c)
        
        # 🚫 필터링할 불필요한 노이즈 태그 목록 정의
        # 짧은 길이, 국가/언어 코드, 불명확한 상태 코드 제거
        NOISE_TAGS = {
            'KO', 'EN', 'JP', 'AI', 'EU', '식', '가능', '불가', 'AI,', 'EU,', 
            '식,', '가능,', '불가,', 'INCI Name', 'CAS No' # 레이블이 태그로 잘못 들어오는 경우 방지
        } 
        
        extracted_tags = []
        for label in chip_labels:
            tag_text = label.text.strip()
            # 텍스트가 비어있지 않고, 노이즈 목록에 없으며, 길이가 2자 초과인 경우만 추출
            if tag_text and tag_text not in NOISE_TAGS and len(tag_text) > 2: 
                extracted_tags.append(tag_text)
                
        details['태그_목록'] = extracted_tags
        
    except Exception as e:
        print(f"   오류 발생: {ingredient_url} 상세 정보 추출 실패: {e}")
        
    return details

# ----------------------------------------------------------------------
# 메인 실행 블록
# ----------------------------------------------------------------------
if __name__ == "__main__":
    # --- 설정 ---
    # ⚠️ 전체 데이터 수집을 위한 최종 설정입니다.
    MAX_PAGE = 1288 
    OUTPUT_FILENAME = "coos_ingredient_database_final.csv"
    
    # 1. 웹 드라이버 설정 (Selenium Manager가 자동으로 드라이버를 찾아 사용합니다.)
    print("🚀 웹 드라이버 초기화 중...")
    try:
        driver = webdriver.Chrome()
    except Exception as e:
        print(f"❌ 드라이버 초기화 실패. Chrome 설치 및 Selenium 버전 확인이 필요합니다: {e}")
        exit()
        
    start_time = time.time()
    
    # 2. 1단계 실행: 모든 상세 URL 수집
    # max_page를 인자로 전달합니다.
    all_urls = scrape_all_ingredient_urls(driver, max_page=MAX_PAGE)
    
    # 3. 2단계 실행: 상세 정보 추출
    print(f"\n==================================================")
    print(f"🔬 2단계: 수집된 {len(all_urls)}개의 URL에서 상세 정보를 추출합니다...")
    print(f"==================================================")
    
    final_data = []
    
    for i, url in enumerate(all_urls):
        data = scrape_ingredient_details(driver, url)
        data['상세_URL'] = url
        final_data.append(data)
        
        # 진행 상황 출력
        if (i + 1) % 50 == 0 or (i + 1) == len(all_urls) or i == 0:
            print(f"   진행 상황: {i + 1} / {len(all_urls)} ({((i + 1) / len(all_urls) * 100):.1f}%) 추출 완료")

    # 4. 드라이버 종료
    driver.quit()
    
    end_time = time.time()
    
    # 5. 데이터 저장 및 정리
    df = pd.DataFrame(final_data)
    
    # 리스트 형태의 태그 목록을 문자열로 변환하여 CSV에 저장
    df['태그_목록'] = df['태그_목록'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
    
    df.to_csv(OUTPUT_FILENAME, index=False, encoding='utf-8-sig')
    
    print(f"\n==================================================")
    print(f"🎉 작업 완료!")
    print(f"총 소요 시간: {end_time - start_time:.2f}초")
    print(f"최종 데이터 파일: {OUTPUT_FILENAME}")
    print(f"총 {len(df)}개 성분 저장 완료.")
    print(f"==================================================")
# Out:
# 🚀 웹 드라이버 초기화 중...
# ==================================================
# 🔎 1단계: 총 1288 페이지를 탐색하여 성분 URL을 수집합니다...
# ==================================================
#    탐색 중: Page 1 / 1288 | 현재 URL 수: 20개
#    탐색 중: Page 100 / 1288 | 현재 URL 수: 2000개
#    탐색 중: Page 200 / 1288 | 현재 URL 수: 3998개
#    탐색 중: Page 300 / 1288 | 현재 URL 수: 5998개
#    탐색 중: Page 400 / 1288 | 현재 URL 수: 7998개
#    탐색 중: Page 500 / 1288 | 현재 URL 수: 9998개
#    탐색 중: Page 600 / 1288 | 현재 URL 수: 11998개
#    탐색 중: Page 700 / 1288 | 현재 URL 수: 13998개
#    탐색 중: Page 800 / 1288 | 현재 URL 수: 15998개
#    탐색 중: Page 900 / 1288 | 현재 URL 수: 17998개
#    탐색 중: Page 1000 / 1288 | 현재 URL 수: 19998개
#    탐색 중: Page 1100 / 1288 | 현재 URL 수: 21998개
#    탐색 중: Page 1200 / 1288 | 현재 URL 수: 23998개
#    탐색 중: Page 1288 / 1288 | 현재 URL 수: 25750개
# ✅ 1단계 완료: 총 25750개의 성분 상세 URL 수집 완료.
#
# ==================================================
# 🔬 2단계: 수집된 25750개의 URL에서 상세 정보를 추출합니다...
# ==================================================
#    진행 상황: 1 / 25750 (0.0%) 추출 완료
#    진행 상황: 50 / 25750 (0.2%) 추출 완료
#    진행 상황: 100 / 25750 (0.4%) 추출 완료
#    진행 상황: 150 / 25750 (0.6%) 추출 완료
#    진행 상황: 200 / 25750 (0.8%) 추출 완료
#    진행 상황: 250 / 25750 (1.0%) 추출 완료
#    진행 상황: 300 / 25750 (1.2%) 추출 완료
#    진행 상황: 350 / 25750 (1.4%) 추출 완료
#    진행 상황: 400 / 25750 (1.6%) 추출 완료
#    진행 상황: 450 / 25750 (1.7%) 추출 완료
#    진행 상황: 500 / 25750 (1.9%) 추출 완료
#    진행 상황: 550 / 25750 (2.1%) 추출 완료
#    진행 상황: 600 / 25750 (2.3%) 추출 완료
#    진행 상황: 650 / 25750 (2.5%) 추출 완료
#    진행 상황: 700 / 25750 (2.7%) 추출 완료
#    진행 상황: 750 / 25750 (2.9%) 추출 완료
#    진행 상황: 800 / 25750 (3.1%) 추출 완료
#    진행 상황: 850 / 25750 (3.3%) 추출 완료
#    진행 상황: 900 / 25750 (3.5%) 추출 완료
#    진행 상황: 950 / 25750 (3.7%) 추출 완료
#    진행 상황: 1000 / 25750 (3.9%) 추출 완료
#    진행 상황: 1050 / 25750 (4.1%) 추출 완료
#    진행 상황: 1100 / 25750 (4.3%) 추출 완료
#    진행 상황: 1150 / 25750 (4.5%) 추출 완료
#    진행 상황: 1200 / 25750 (4.7%) 추출 완료
#    진행 상황: 1250 / 25750 (4.9%) 추출 완료
#    진행 상황: 1300 / 25750 (5.0%) 추출 완료
#    진행 상황: 1350 / 25750 (5.2%) 추출 완료
#    진행 상황: 1400 / 25750 (5.4%) 추출 완료
#    진행 상황: 1450 / 25750 (5.6%) 추출 완료
#    진행 상황: 1500 / 25750 (5.8%) 추출 완료
#    진행 상황: 1550 / 25750 (6.0%) 추출 완료
#    진행 상황: 1600 / 25750 (6.2%) 추출 완료
#    진행 상황: 1650 / 25750 (6.4%) 추출 완료
#    진행 상황: 1700 / 25750 (6.6%) 추출 완료
#    진행 상황: 1750 / 25750 (6.8%) 추출 완료
#    진행 상황: 1800 / 25750 (7.0%) 추출 완료
#    진행 상황: 1850 / 25750 (7.2%) 추출 완료
#    진행 상황: 1900 / 25750 (7.4%) 추출 완료
#    진행 상황: 1950 / 25750 (7.6%) 추출 완료
#    진행 상황: 2000 / 25750 (7.8%) 추출 완료
#    진행 상황: 2050 / 25750 (8.0%) 추출 완료
#    진행 상황: 2100 / 25750 (8.2%) 추출 완료
#    진행 상황: 2150 / 25750 (8.3%) 추출 완료
#    진행 상황: 2200 / 25750 (8.5%) 추출 완료
#    진행 상황: 2250 / 25750 (8.7%) 추출 완료
#    진행 상황: 2300 / 25750 (8.9%) 추출 완료
#    진행 상황: 2350 / 25750 (9.1%) 추출 완료
#    진행 상황: 2400 / 25750 (9.3%) 추출 완료
#    진행 상황: 2450 / 25750 (9.5%) 추출 완료
#    진행 상황: 2500 / 25750 (9.7%) 추출 완료
#    진행 상황: 2550 / 25750 (9.9%) 추출 완료
#    진행 상황: 2600 / 25750 (10.1%) 추출 완료
#    진행 상황: 2650 / 25750 (10.3%) 추출 완료
#    진행 상황: 2700 / 25750 (10.5%) 추출 완료
#    진행 상황: 2750 / 25750 (10.7%) 추출 완료
#    진행 상황: 2800 / 25750 (10.9%) 추출 완료
#    진행 상황: 2850 / 25750 (11.1%) 추출 완료
#    진행 상황: 2900 / 25750 (11.3%) 추출 완료
#    진행 상황: 2950 / 25750 (11.5%) 추출 완료
#    진행 상황: 3000 / 25750 (11.7%) 추출 완료
#    진행 상황: 3050 / 25750 (11.8%) 추출 완료
#    진행 상황: 3100 / 25750 (12.0%) 추출 완료
#    진행 상황: 3150 / 25750 (12.2%) 추출 완료
#    진행 상황: 3200 / 25750 (12.4%) 추출 완료
#    진행 상황: 3250 / 25750 (12.6%) 추출 완료
#    진행 상황: 3300 / 25750 (12.8%) 추출 완료
#    진행 상황: 3350 / 25750 (13.0%) 추출 완료
#    진행 상황: 3400 / 25750 (13.2%) 추출 완료
#    진행 상황: 3450 / 25750 (13.4%) 추출 완료
#    진행 상황: 3500 / 25750 (13.6%) 추출 완료
#    진행 상황: 3550 / 25750 (13.8%) 추출 완료
#    진행 상황: 3600 / 25750 (14.0%) 추출 완료
#    진행 상황: 3650 / 25750 (14.2%) 추출 완료
#    진행 상황: 3700 / 25750 (14.4%) 추출 완료
#    진행 상황: 3750 / 25750 (14.6%) 추출 완료
#    진행 상황: 3800 / 25750 (14.8%) 추출 완료
#    진행 상황: 3850 / 25750 (15.0%) 추출 완료
#    진행 상황: 3900 / 25750 (15.1%) 추출 완료
#    진행 상황: 3950 / 25750 (15.3%) 추출 완료
#    진행 상황: 4000 / 25750 (15.5%) 추출 완료
#    진행 상황: 4050 / 25750 (15.7%) 추출 완료
#    진행 상황: 4100 / 25750 (15.9%) 추출 완료
#    진행 상황: 4150 / 25750 (16.1%) 추출 완료
#    진행 상황: 4200 / 25750 (16.3%) 추출 완료
#    진행 상황: 4250 / 25750 (16.5%) 추출 완료
#    진행 상황: 4300 / 25750 (16.7%) 추출 완료
#    진행 상황: 4350 / 25750 (16.9%) 추출 완료
#    진행 상황: 4400 / 25750 (17.1%) 추출 완료
#    진행 상황: 4450 / 25750 (17.3%) 추출 완료
#    진행 상황: 4500 / 25750 (17.5%) 추출 완료
#    진행 상황: 4550 / 25750 (17.7%) 추출 완료
#    진행 상황: 4600 / 25750 (17.9%) 추출 완료
#    진행 상황: 4650 / 25750 (18.1%) 추출 완료
#    진행 상황: 4700 / 25750 (18.3%) 추출 완료
#    진행 상황: 4750 / 25750 (18.4%) 추출 완료
#    진행 상황: 4800 / 25750 (18.6%) 추출 완료
#    진행 상황: 4850 / 25750 (18.8%) 추출 완료
#    진행 상황: 4900 / 25750 (19.0%) 추출 완료
#    진행 상황: 4950 / 25750 (19.2%) 추출 완료
#    진행 상황: 5000 / 25750 (19.4%) 추출 완료
#    진행 상황: 5050 / 25750 (19.6%) 추출 완료
#    진행 상황: 5100 / 25750 (19.8%) 추출 완료
#    진행 상황: 5150 / 25750 (20.0%) 추출 완료
#    진행 상황: 5200 / 25750 (20.2%) 추출 완료
#    진행 상황: 5250 / 25750 (20.4%) 추출 완료
#    진행 상황: 5300 / 25750 (20.6%) 추출 완료
#    진행 상황: 5350 / 25750 (20.8%) 추출 완료
#    진행 상황: 5400 / 25750 (21.0%) 추출 완료
#    진행 상황: 5450 / 25750 (21.2%) 추출 완료
#    진행 상황: 5500 / 25750 (21.4%) 추출 완료
#    진행 상황: 5550 / 25750 (21.6%) 추출 완료
#    진행 상황: 5600 / 25750 (21.7%) 추출 완료
#    진행 상황: 5650 / 25750 (21.9%) 추출 완료
#    진행 상황: 5700 / 25750 (22.1%) 추출 완료
#    진행 상황: 5750 / 25750 (22.3%) 추출 완료
#    진행 상황: 5800 / 25750 (22.5%) 추출 완료
#    진행 상황: 5850 / 25750 (22.7%) 추출 완료
#    진행 상황: 5900 / 25750 (22.9%) 추출 완료
#    진행 상황: 5950 / 25750 (23.1%) 추출 완료
#    진행 상황: 6000 / 25750 (23.3%) 추출 완료
#    진행 상황: 6050 / 25750 (23.5%) 추출 완료
#    진행 상황: 6100 / 25750 (23.7%) 추출 완료
#    진행 상황: 6150 / 25750 (23.9%) 추출 완료
#    진행 상황: 6200 / 25750 (24.1%) 추출 완료
#    진행 상황: 6250 / 25750 (24.3%) 추출 완료
#    진행 상황: 6300 / 25750 (24.5%) 추출 완료
#    진행 상황: 6350 / 25750 (24.7%) 추출 완료
#    진행 상황: 6400 / 25750 (24.9%) 추출 완료
#    진행 상황: 6450 / 25750 (25.0%) 추출 완료
#    진행 상황: 6500 / 25750 (25.2%) 추출 완료
#    진행 상황: 6550 / 25750 (25.4%) 추출 완료
#    진행 상황: 6600 / 25750 (25.6%) 추출 완료
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     717 try:
# --> 718     return self._sock.recv_into(b)
#     719 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# Cell In[5], line 162
#     159 final_data = []
#     161 for i, url in enumerate(all_urls):
# --> 162     data = scrape_ingredient_details(driver, url)
#     163     data['상세_URL'] = url
#     164     final_data.append(data)
#
# Cell In[5], line 64, in scrape_ingredient_details(driver, ingredient_url)
#      59 def scrape_ingredient_details(driver, ingredient_url):
#      60     """
#      61     성분 상세 페이지에서 한글명, 영문명, CAS No. 및 태그 정보를 추출합니다.
#      62     (태그 목록에서 불필요한 노이즈 코드 제거 로직 포함)
#      63     """
# ---> 64     driver.get(ingredient_url)
#      65     time.sleep(1) # 로딩 대기
#      67     details = {
#      68         '원료명': unquote(ingredient_url.split('/')[-1]),
#      69         '영문명': None,
#    (...)     72         '태그_목록': []
#      73     }
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:483, in WebDriver.get(self, url)
#     465 def get(self, url: str) -> None:
#     466     """Navigate the browser to the specified URL in the current window or
#     467     tab.
#     468
#    (...)    481     >>> driver.get("https://example.com")
#     482     """
# --> 483     self.execute(Command.GET, {"url": url})
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.execute(self, driver_command, params)
#     452     elif "sessionId" not in params:
#     453         params["sessionId"] = self.session_id
# --> 455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
#     458     self.error_handler.check_response(response)
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:406, in RemoteConnection.execute(self, command, params)
#     404 trimmed = self._trim_large_entries(params)
#     405 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 406 return self._request(command_info[0], url, body=data)
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:430, in RemoteConnection._request(self, method, url, body)
#     427     body = None
#     429 if self._client_config.keep_alive:
# --> 430     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     431     statuscode = response.status
#     432 else:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     838 elif isinstance(new_e, (OSError, HTTPException)):
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     471 elif error and self._is_read_error(error):
#     472     # Read retry?
#     473     if read is False or method is None or not self._is_method_retryable(method):
# --> 474         raise reraise(type(error), error, _stacktrace)
#     475     elif read is not None:
#     476         read -= 1
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      37     if value.__traceback__ is not tb:
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#      41     value = None  # type: ignore[assignment]
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#     539 # Set properties that are used by the pooling layer.
#
# File ~/Desktop/github/Project_A/.conda/lib/python3.11/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     364 """Is the error actually a timeout? Will raise a ReadTimeout or pass"""
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#     372 if hasattr(err, "errno") and err.errno in _blocking_errnos:
#
# ReadTimeoutError: HTTPConnectionPool(host='localhost', port=64907): Read timed out. (read timeout=120)

# %%
import time
import pandas as pd
import random # 🌟 무작위 대기 시간 적용을 위해 추가
import os # 🌟 파일 존재 여부 확인을 위해 추가
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote

# ----------------------------------------------------------------------
# 1단계: 모든 상세 URL 수집 함수 (지연 시간 강화 및 페이지 재개 기능 포함)
# ----------------------------------------------------------------------
def scrape_all_ingredient_urls(driver, max_page, url_file, last_page_file):
    """
    페이지네이션을 이용하여 모든 성분 상세 페이지의 URL을 수집합니다.
    """
    BASE_URL = "https://coos.kr"
    all_detail_urls = set()
    
    # 🌟 1-1. 기존 URL 파일에서 URL 목록 로드 (만약 1단계가 완전히 완료되지 않았을 경우)
    if os.path.exists(url_file):
        try:
            with open(url_file, 'r', encoding='utf-8') as f:
                loaded_urls = {line.strip() for line in f if line.strip()}
            all_detail_urls.update(loaded_urls)
            print(f"   -> 기존 URL 파일에서 {len(all_detail_urls)}개의 URL을 로드했습니다.")
        except:
             print("   -> 기존 URL 파일 로드에 실패했습니다. 처음부터 URL을 수집합니다.")

    # 🌟 1-2. 마지막 성공 페이지 번호 로드
    start_page = 1
    if os.path.exists(last_page_file):
        try:
            with open(last_page_file, 'r') as f:
                start_page = int(f.read().strip())
                # 이미 처리된 페이지는 건너뜁니다.
                print(f"   ✅ 1단계 재개: {start_page} 페이지부터 탐색을 시작합니다.")
        except:
            pass # 파일이 손상되었다면 1부터 시작

    print(f"==================================================")
    print(f"🔎 1단계: 총 {max_page} 페이지 중 {start_page} 페이지부터 탐색을 시작합니다...")
    print(f"==================================================")
    
    for page_num in range(start_page, max_page + 1):
        list_url = f"{BASE_URL}/ingredients?page={page_num}"
        
        try:
            driver.get(list_url)
            # 🌟 대기 시간 강화: 1.5초 ~ 3.5초 사이의 무작위 대기
            time.sleep(random.uniform(1.5, 3.5)) 
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            
            link_tags = soup.find_all(
                'a', 
                href=lambda href: href and href.startswith('/ingredients/') and '?' not in href
            )
            
            # 수집 및 중복 제거
            new_urls = []
            for tag in link_tags:
                url_path = tag['href']
                full_url = urljoin(BASE_URL, url_path)
                if full_url not in all_detail_urls:
                    all_detail_urls.add(full_url)
                    new_urls.append(full_url)
            
            # 🌟 페이지 성공 시 현재 페이지 번호 저장 및 수집된 URL 목록 추가 저장
            with open(last_page_file, 'w') as f:
                f.write(str(page_num + 1)) # 다음 시작 페이지를 저장

            with open(url_file, 'a', encoding='utf-8') as f:
                for url in new_urls:
                    f.write(f"{url}\n")
            
            # 🌟 매 100페이지마다 더 긴 휴식 시간을 가집니다. (서버 부하 감소)
            if page_num % 100 == 0:
                print(f"   === 100페이지 휴식 시작 (10초) ===")
                time.sleep(10)
                
            if page_num % 50 == 0 or page_num == max_page:
                print(f"   탐색 완료: Page {page_num} / {max_page} | 현재 URL 수: {len(all_detail_urls)}개")

        except Exception as e:
            print(f"⚠️ Page {page_num} 로딩 중 오류 발생 ({e}). {last_page_file}에 저장 후 종료 대기...")
            time.sleep(5) # 오류 발생 시 추가 대기 후 재시도
            # 오류 발생 시 마지막 성공 페이지가 저장되어 있으므로, 프로그램이 종료되어도 재개 가능
            raise # 오류 발생 시 스크립트를 중단하여 재실행을 유도

    # 🌟 모든 페이지 탐색이 성공적으로 완료되면 페이지 추적 파일을 삭제합니다.
    if os.path.exists(last_page_file):
        os.remove(last_page_file)
            
    print(f"✅ 1단계 완료: 총 {len(all_detail_urls)}개의 성분 상세 URL 수집 완료.")
    return list(all_detail_urls)

# ----------------------------------------------------------------------
# 2단계: 상세 페이지 정보 추출 함수 (태그 노이즈 필터링 적용)
# ----------------------------------------------------------------------
def scrape_ingredient_details(driver, ingredient_url):
    driver.get(ingredient_url)
    # 🌟 대기 시간 강화: 1초 ~ 2.5초 사이의 무작위 대기
    time.sleep(random.uniform(1.0, 2.5)) 
    
    details = {
        '원료명': unquote(ingredient_url.split('/')[-1]), 
        '영문명': None,
        'CAS_No': None,
        '설명_요약': None,
        '태그_목록': []
    }
    
    try:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        # 1. 원료명 (한글) 추출: <h1> 태그
        h1_tag = soup.find('h1')
        if h1_tag:
            details['원료명'] = h1_tag.text.strip()
            
            # 2. 영문명 추출: <h1> 바로 다음의 div
            english_name_div = h1_tag.find_next_sibling('div', style=lambda s: s and 'font-size' in s)
            if english_name_div:
                 details['영문명'] = english_name_div.text.strip()
                 
        # 3. CAS No. 및 상세 정보 추출: <dt> (레이블) / <dd> (값) 쌍 검색
        info_items = soup.find_all(['dt', 'dd'])
        for i in range(len(info_items) - 1):
            if info_items[i].name == 'dt':
                label = info_items[i].text.strip()
                value_tag = info_items[i+1]
                value = value_tag.text.strip() if value_tag and value_tag.name == 'dd' else None
                
                if value and value.lower() != 'none':
                    if 'INCI Name' in label and not details['영문명']:
                        details['영문명'] = value
                    elif 'CAS No' in label:
                        details['CAS_No'] = value

        # 4. 설명 요약 추출: CSS 클래스 기반
        summary_div = soup.find('div', class_=lambda c: c and 'css-m3enaf' in c)
        if summary_div:
            details['설명_요약'] = summary_div.text.strip()
            
        # 5. 태그/칩 목록 추출 및 필터링
        chip_labels = soup.find_all('span', class_=lambda c: c and 'MuiChip-label' in c)
        NOISE_TAGS = {
            'KO', 'EN', 'JP', 'AI', 'EU', '식', '가능', '불가', 'AI,', 'EU,', 
            '식,', '가능,', '불가,', 'INCI Name', 'CAS No' 
        } 
        
        extracted_tags = []
        for label in chip_labels:
            tag_text = label.text.strip()
            if tag_text and tag_text not in NOISE_TAGS and len(tag_text) > 2: 
                extracted_tags.append(tag_text)
                
        details['태그_목록'] = extracted_tags
        
    except Exception as e:
        print(f"   오류 발생: {ingredient_url} 상세 정보 추출 실패: {e}")
        time.sleep(3) # 상세 페이지 오류 시 추가 대기
        
    return details

# ----------------------------------------------------------------------
# 메인 실행 블록
# ----------------------------------------------------------------------
if __name__ == "__main__":
    # --- 설정 ---
    MAX_PAGE = 1288 
    OUTPUT_FILENAME = "coos_ingredient_database.csv"
    # 🌟 1단계 URL 수집 재개를 위한 파일 추가
    URL_LIST_FILE = "coos_all_urls.txt"
    LAST_PAGE_FILE = "last_scraped_page.txt"
    
    # 1. 웹 드라이버 설정
    print("🚀 웹 드라이버 초기화 중...")
    try:
        driver = webdriver.Chrome()
    except Exception as e:
        print(f"❌ 드라이버 초기화 실패. Chrome 설치 및 Selenium 버전 확인이 필요합니다: {e}")
        exit()
        
    start_time = time.time()
    
    # 2. 1단계 실행: 모든 상세 URL 수집 (페이지 재개 기능 사용)
    try:
        all_urls = scrape_all_ingredient_urls(driver, max_page=MAX_PAGE, url_file=URL_LIST_FILE, last_page_file=LAST_PAGE_FILE)
    except Exception as e:
        # 1단계에서 오류가 나면 드라이버만 닫고 종료하여 재실행을 준비합니다.
        print(f"\n❌ 1단계 URL 수집 중 치명적인 오류 발생: {e}. 다음 재실행 시 {LAST_PAGE_FILE}부터 재개됩니다.")
        driver.quit()
        exit()
    
    # 🌟 3. 재개 로직 적용 및 URL 목록 필터링 (2단계)
    scraped_urls = set()
    existing_data = []

    if os.path.exists(OUTPUT_FILENAME):
        print(f"\n✅ 기존 상세 데이터 파일 '{OUTPUT_FILENAME}' 발견. 2단계 재개를 시도합니다.")
        try:
            df_existing = pd.read_csv(OUTPUT_FILENAME, encoding='utf-8-sig')
            scraped_urls = set(df_existing['상세_URL'].dropna())
            existing_data = df_existing.to_dict('records')
            
            existing_data = [d for d in existing_data if d.get('상세_URL')] 
            print(f"   -> 이미 {len(scraped_urls)}개의 성분 데이터가 수집되어 있습니다. 미수집 URL만 처리합니다.")
        except Exception as e:
             print(f"   -> 기존 파일을 읽는 중 오류 발생 ({e}). 처음부터 2단계 수집을 시작합니다.")

    # 미수집된 URL만 남깁니다.
    pending_urls = [url for url in all_urls if url not in scraped_urls]
    
    print(f"\n==================================================")
    print(f"🔬 2단계: 미처리된 {len(pending_urls)}개의 URL에서 상세 정보를 추출합니다...")
    print(f"==================================================")
    
    final_data = existing_data # 기존 데이터 + 새로 수집할 데이터

    for i, url in enumerate(pending_urls):
        
        data = scrape_ingredient_details(driver, url)
        data['상세_URL'] = url
        final_data.append(data)
        
        # 🌟 매 100개마다 중간 저장 (데이터 유실 방지)
        if (len(final_data) - len(existing_data)) % 100 == 0 and (len(final_data) - len(existing_data)) > 0:
            df_temp = pd.DataFrame(final_data)
            df_temp['태그_목록'] = df_temp['태그_목록'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
            df_temp.to_csv(OUTPUT_FILENAME, index=False, encoding='utf-8-sig')
            print(f"   [중간 저장] 현재까지 총 {len(final_data)}개 성분 저장 완료.")

        current_processed = i + 1
        total_pending = len(pending_urls)
        
        if current_processed % 50 == 0 or current_processed == total_pending or current_processed == 1:
            total_scraped_now = len(existing_data) + current_processed
            print(f"   진행 상황: {current_processed} / {total_pending} 미처리 항목 완료 | 총 {total_scraped_now}개 ({total_scraped_now / len(all_urls) * 100:.1f}%)")


    # 4. 드라이버 종료
    driver.quit()
    
    end_time = time.time()
    
    # 5. 최종 데이터 저장 및 정리
    df = pd.DataFrame(final_data)
    
    # 리스트 형태의 태그 목록을 문자열로 변환하여 CSV에 저장
    df['태그_목록'] = df['태그_목록'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
    
    df.to_csv(OUTPUT_FILENAME, index=False, encoding='utf-8-sig')
    
    print(f"\n==================================================")
    print(f"🎉 작업 완료!")
    print(f"총 소요 시간: {end_time - start_time:.2f}초")
    print(f"최종 데이터 파일: {OUTPUT_FILENAME}")
    print(f"총 {len(df)}개 성분 저장 완료.")
    print(f"==================================================")
# Out:
# 🚀 웹 드라이버 초기화 중...
#    -> 기존 URL 파일에서 25750개의 URL을 로드했습니다.
#    ✅ 1단계 재개: 1287 페이지부터 탐색을 시작합니다.
# ==================================================
# 🔎 1단계: 총 1288 페이지 중 1287 페이지부터 탐색을 시작합니다...
# ==================================================
#    탐색 완료: Page 1288 / 1288 | 현재 URL 수: 25750개
# ✅ 1단계 완료: 총 25750개의 성분 상세 URL 수집 완료.
#
# ✅ 기존 상세 데이터 파일 'coos_ingredient_database.csv' 발견. 2단계 재개를 시도합니다.
#    -> 이미 60개의 성분 데이터가 수집되어 있습니다. 미수집 URL만 처리합니다.
#
# ==================================================
# 🔬 2단계: 미처리된 25690개의 URL에서 상세 정보를 추출합니다...
# ==================================================
#    진행 상황: 1 / 25690 미처리 항목 완료 | 총 62개 (0.2%)
#    진행 상황: 50 / 25690 미처리 항목 완료 | 총 160개 (0.6%)
#    진행 상황: 100 / 25690 미처리 항목 완료 | 총 260개 (1.0%)
#    진행 상황: 150 / 25690 미처리 항목 완료 | 총 360개 (1.4%)
#    진행 상황: 200 / 25690 미처리 항목 완료 | 총 460개 (1.8%)
#    진행 상황: 250 / 25690 미처리 항목 완료 | 총 560개 (2.2%)
#    진행 상황: 300 / 25690 미처리 항목 완료 | 총 660개 (2.6%)
#    진행 상황: 350 / 25690 미처리 항목 완료 | 총 760개 (3.0%)
#    진행 상황: 400 / 25690 미처리 항목 완료 | 총 860개 (3.3%)
#    진행 상황: 450 / 25690 미처리 항목 완료 | 총 960개 (3.7%)
#    진행 상황: 500 / 25690 미처리 항목 완료 | 총 1060개 (4.1%)
#    진행 상황: 550 / 25690 미처리 항목 완료 | 총 1160개 (4.5%)
#    진행 상황: 600 / 25690 미처리 항목 완료 | 총 1260개 (4.9%)
#    진행 상황: 650 / 25690 미처리 항목 완료 | 총 1360개 (5.3%)
#    진행 상황: 700 / 25690 미처리 항목 완료 | 총 1460개 (5.7%)
#    진행 상황: 750 / 25690 미처리 항목 완료 | 총 1560개 (6.1%)
#    진행 상황: 800 / 25690 미처리 항목 완료 | 총 1660개 (6.4%)
#    진행 상황: 850 / 25690 미처리 항목 완료 | 총 1760개 (6.8%)
#    진행 상황: 900 / 25690 미처리 항목 완료 | 총 1860개 (7.2%)
#    진행 상황: 950 / 25690 미처리 항목 완료 | 총 1960개 (7.6%)
#    진행 상황: 1000 / 25690 미처리 항목 완료 | 총 2060개 (8.0%)
#    진행 상황: 1050 / 25690 미처리 항목 완료 | 총 2160개 (8.4%)
#    진행 상황: 1100 / 25690 미처리 항목 완료 | 총 2260개 (8.8%)
#    진행 상황: 1150 / 25690 미처리 항목 완료 | 총 2360개 (9.2%)
#    진행 상황: 1200 / 25690 미처리 항목 완료 | 총 2460개 (9.6%)
#    진행 상황: 1250 / 25690 미처리 항목 완료 | 총 2560개 (9.9%)
#    진행 상황: 1300 / 25690 미처리 항목 완료 | 총 2660개 (10.3%)
#    진행 상황: 1350 / 25690 미처리 항목 완료 | 총 2760개 (10.7%)
#    진행 상황: 1400 / 25690 미처리 항목 완료 | 총 2860개 (11.1%)
#    진행 상황: 1450 / 25690 미처리 항목 완료 | 총 2960개 (11.5%)
#    진행 상황: 1500 / 25690 미처리 항목 완료 | 총 3060개 (11.9%)
#    진행 상황: 1550 / 25690 미처리 항목 완료 | 총 3160개 (12.3%)
#    진행 상황: 1600 / 25690 미처리 항목 완료 | 총 3260개 (12.7%)
#    진행 상황: 1650 / 25690 미처리 항목 완료 | 총 3360개 (13.0%)
#    진행 상황: 1700 / 25690 미처리 항목 완료 | 총 3460개 (13.4%)
#    진행 상황: 1750 / 25690 미처리 항목 완료 | 총 3560개 (13.8%)
#    진행 상황: 1800 / 25690 미처리 항목 완료 | 총 3660개 (14.2%)
#    진행 상황: 1850 / 25690 미처리 항목 완료 | 총 3760개 (14.6%)
#    진행 상황: 1900 / 25690 미처리 항목 완료 | 총 3860개 (15.0%)
#    진행 상황: 1950 / 25690 미처리 항목 완료 | 총 3960개 (15.4%)
#    진행 상황: 2000 / 25690 미처리 항목 완료 | 총 4060개 (15.8%)
#    진행 상황: 2050 / 25690 미처리 항목 완료 | 총 4160개 (16.2%)
#    진행 상황: 2100 / 25690 미처리 항목 완료 | 총 4260개 (16.5%)
#    진행 상황: 2150 / 25690 미처리 항목 완료 | 총 4360개 (16.9%)
#    진행 상황: 2200 / 25690 미처리 항목 완료 | 총 4460개 (17.3%)
#    진행 상황: 2250 / 25690 미처리 항목 완료 | 총 4560개 (17.7%)
#    진행 상황: 2300 / 25690 미처리 항목 완료 | 총 4660개 (18.1%)
#    진행 상황: 2350 / 25690 미처리 항목 완료 | 총 4760개 (18.5%)
#    진행 상황: 2400 / 25690 미처리 항목 완료 | 총 4860개 (18.9%)
#    진행 상황: 2450 / 25690 미처리 항목 완료 | 총 4960개 (19.3%)
#    진행 상황: 2500 / 25690 미처리 항목 완료 | 총 5060개 (19.7%)
#    진행 상황: 2550 / 25690 미처리 항목 완료 | 총 5160개 (20.0%)
#    진행 상황: 2600 / 25690 미처리 항목 완료 | 총 5260개 (20.4%)
#    진행 상황: 2650 / 25690 미처리 항목 완료 | 총 5360개 (20.8%)
#    진행 상황: 2700 / 25690 미처리 항목 완료 | 총 5460개 (21.2%)
#    진행 상황: 2750 / 25690 미처리 항목 완료 | 총 5560개 (21.6%)
#    진행 상황: 2800 / 25690 미처리 항목 완료 | 총 5660개 (22.0%)
#    진행 상황: 2850 / 25690 미처리 항목 완료 | 총 5760개 (22.4%)
#    진행 상황: 2900 / 25690 미처리 항목 완료 | 총 5860개 (22.8%)
#    진행 상황: 2950 / 25690 미처리 항목 완료 | 총 5960개 (23.1%)
#    진행 상황: 3000 / 25690 미처리 항목 완료 | 총 6060개 (23.5%)
#    진행 상황: 3050 / 25690 미처리 항목 완료 | 총 6160개 (23.9%)
#    진행 상황: 3100 / 25690 미처리 항목 완료 | 총 6260개 (24.3%)
#    진행 상황: 3150 / 25690 미처리 항목 완료 | 총 6360개 (24.7%)
#    진행 상황: 3200 / 25690 미처리 항목 완료 | 총 6460개 (25.1%)
#    진행 상황: 3250 / 25690 미처리 항목 완료 | 총 6560개 (25.5%)
#    진행 상황: 3300 / 25690 미처리 항목 완료 | 총 6660개 (25.9%)
#    진행 상황: 3350 / 25690 미처리 항목 완료 | 총 6760개 (26.3%)
#    진행 상황: 3400 / 25690 미처리 항목 완료 | 총 6860개 (26.6%)
#    진행 상황: 3450 / 25690 미처리 항목 완료 | 총 6960개 (27.0%)
#    진행 상황: 3500 / 25690 미처리 항목 완료 | 총 7060개 (27.4%)
#    진행 상황: 3550 / 25690 미처리 항목 완료 | 총 7160개 (27.8%)
#    진행 상황: 3600 / 25690 미처리 항목 완료 | 총 7260개 (28.2%)
#    진행 상황: 3650 / 25690 미처리 항목 완료 | 총 7360개 (28.6%)
#    진행 상황: 3700 / 25690 미처리 항목 완료 | 총 7460개 (29.0%)
#    진행 상황: 3750 / 25690 미처리 항목 완료 | 총 7560개 (29.4%)
#    진행 상황: 3800 / 25690 미처리 항목 완료 | 총 7660개 (29.7%)
#    진행 상황: 3850 / 25690 미처리 항목 완료 | 총 7760개 (30.1%)
#    진행 상황: 3900 / 25690 미처리 항목 완료 | 총 7860개 (30.5%)
#    진행 상황: 3950 / 25690 미처리 항목 완료 | 총 7960개 (30.9%)
#    진행 상황: 4000 / 25690 미처리 항목 완료 | 총 8060개 (31.3%)
#    진행 상황: 4050 / 25690 미처리 항목 완료 | 총 8160개 (31.7%)
#    진행 상황: 4100 / 25690 미처리 항목 완료 | 총 8260개 (32.1%)
#    진행 상황: 4150 / 25690 미처리 항목 완료 | 총 8360개 (32.5%)
#    진행 상황: 4200 / 25690 미처리 항목 완료 | 총 8460개 (32.9%)
#    진행 상황: 4250 / 25690 미처리 항목 완료 | 총 8560개 (33.2%)
#    진행 상황: 4300 / 25690 미처리 항목 완료 | 총 8660개 (33.6%)
#    진행 상황: 4350 / 25690 미처리 항목 완료 | 총 8760개 (34.0%)
#    진행 상황: 4400 / 25690 미처리 항목 완료 | 총 8860개 (34.4%)
#    진행 상황: 4450 / 25690 미처리 항목 완료 | 총 8960개 (34.8%)
#    진행 상황: 4500 / 25690 미처리 항목 완료 | 총 9060개 (35.2%)
#    진행 상황: 4550 / 25690 미처리 항목 완료 | 총 9160개 (35.6%)
#    진행 상황: 4600 / 25690 미처리 항목 완료 | 총 9260개 (36.0%)
#    진행 상황: 4650 / 25690 미처리 항목 완료 | 총 9360개 (36.3%)
#    진행 상황: 4700 / 25690 미처리 항목 완료 | 총 9460개 (36.7%)
#    진행 상황: 4750 / 25690 미처리 항목 완료 | 총 9560개 (37.1%)
#    진행 상황: 4800 / 25690 미처리 항목 완료 | 총 9660개 (37.5%)
#    진행 상황: 4850 / 25690 미처리 항목 완료 | 총 9760개 (37.9%)
#    진행 상황: 4900 / 25690 미처리 항목 완료 | 총 9860개 (38.3%)
#    진행 상황: 4950 / 25690 미처리 항목 완료 | 총 9960개 (38.7%)
#    진행 상황: 5000 / 25690 미처리 항목 완료 | 총 10060개 (39.1%)
#    진행 상황: 5050 / 25690 미처리 항목 완료 | 총 10160개 (39.5%)
#    진행 상황: 5100 / 25690 미처리 항목 완료 | 총 10260개 (39.8%)
#    진행 상황: 5150 / 25690 미처리 항목 완료 | 총 10360개 (40.2%)
#    진행 상황: 5200 / 25690 미처리 항목 완료 | 총 10460개 (40.6%)
#    진행 상황: 5250 / 25690 미처리 항목 완료 | 총 10560개 (41.0%)
#    진행 상황: 5300 / 25690 미처리 항목 완료 | 총 10660개 (41.4%)
#    진행 상황: 5350 / 25690 미처리 항목 완료 | 총 10760개 (41.8%)
#    진행 상황: 5400 / 25690 미처리 항목 완료 | 총 10860개 (42.2%)
#    진행 상황: 5450 / 25690 미처리 항목 완료 | 총 10960개 (42.6%)
#    진행 상황: 5500 / 25690 미처리 항목 완료 | 총 11060개 (43.0%)
#    진행 상황: 5550 / 25690 미처리 항목 완료 | 총 11160개 (43.3%)
#    진행 상황: 5600 / 25690 미처리 항목 완료 | 총 11260개 (43.7%)
#    진행 상황: 5650 / 25690 미처리 항목 완료 | 총 11360개 (44.1%)
#    진행 상황: 5700 / 25690 미처리 항목 완료 | 총 11460개 (44.5%)
#    진행 상황: 5750 / 25690 미처리 항목 완료 | 총 11560개 (44.9%)
#    진행 상황: 5800 / 25690 미처리 항목 완료 | 총 11660개 (45.3%)
#    진행 상황: 5850 / 25690 미처리 항목 완료 | 총 11760개 (45.7%)
#    진행 상황: 5900 / 25690 미처리 항목 완료 | 총 11860개 (46.1%)
#    진행 상황: 5950 / 25690 미처리 항목 완료 | 총 11960개 (46.4%)
#    진행 상황: 6000 / 25690 미처리 항목 완료 | 총 12060개 (46.8%)
#    진행 상황: 6050 / 25690 미처리 항목 완료 | 총 12160개 (47.2%)
#    진행 상황: 6100 / 25690 미처리 항목 완료 | 총 12260개 (47.6%)
#    진행 상황: 6150 / 25690 미처리 항목 완료 | 총 12360개 (48.0%)
#    진행 상황: 6200 / 25690 미처리 항목 완료 | 총 12460개 (48.4%)
#    진행 상황: 6250 / 25690 미처리 항목 완료 | 총 12560개 (48.8%)
#    진행 상황: 6300 / 25690 미처리 항목 완료 | 총 12660개 (49.2%)
#    진행 상황: 6350 / 25690 미처리 항목 완료 | 총 12760개 (49.6%)
#    진행 상황: 6400 / 25690 미처리 항목 완료 | 총 12860개 (49.9%)
#    진행 상황: 6450 / 25690 미처리 항목 완료 | 총 12960개 (50.3%)
#    진행 상황: 6500 / 25690 미처리 항목 완료 | 총 13060개 (50.7%)
#    진행 상황: 6550 / 25690 미처리 항목 완료 | 총 13160개 (51.1%)
#    진행 상황: 6600 / 25690 미처리 항목 완료 | 총 13260개 (51.5%)
#    진행 상황: 6650 / 25690 미처리 항목 완료 | 총 13360개 (51.9%)
#    진행 상황: 6700 / 25690 미처리 항목 완료 | 총 13460개 (52.3%)
#    진행 상황: 6750 / 25690 미처리 항목 완료 | 총 13560개 (52.7%)
#    진행 상황: 6800 / 25690 미처리 항목 완료 | 총 13660개 (53.0%)
#    진행 상황: 6850 / 25690 미처리 항목 완료 | 총 13760개 (53.4%)
#    진행 상황: 6900 / 25690 미처리 항목 완료 | 총 13860개 (53.8%)
#    진행 상황: 6950 / 25690 미처리 항목 완료 | 총 13960개 (54.2%)
#    진행 상황: 7000 / 25690 미처리 항목 완료 | 총 14060개 (54.6%)
#    진행 상황: 7050 / 25690 미처리 항목 완료 | 총 14160개 (55.0%)
#    진행 상황: 7100 / 25690 미처리 항목 완료 | 총 14260개 (55.4%)
#    진행 상황: 7150 / 25690 미처리 항목 완료 | 총 14360개 (55.8%)
#    진행 상황: 7200 / 25690 미처리 항목 완료 | 총 14460개 (56.2%)
#    진행 상황: 7250 / 25690 미처리 항목 완료 | 총 14560개 (56.5%)
#    진행 상황: 7300 / 25690 미처리 항목 완료 | 총 14660개 (56.9%)
#    진행 상황: 7350 / 25690 미처리 항목 완료 | 총 14760개 (57.3%)
#    진행 상황: 7400 / 25690 미처리 항목 완료 | 총 14860개 (57.7%)
#    진행 상황: 7450 / 25690 미처리 항목 완료 | 총 14960개 (58.1%)
#    진행 상황: 7500 / 25690 미처리 항목 완료 | 총 15060개 (58.5%)
#    진행 상황: 7550 / 25690 미처리 항목 완료 | 총 15160개 (58.9%)
#    진행 상황: 7600 / 25690 미처리 항목 완료 | 총 15260개 (59.3%)
#    진행 상황: 7650 / 25690 미처리 항목 완료 | 총 15360개 (59.7%)
#    진행 상황: 7700 / 25690 미처리 항목 완료 | 총 15460개 (60.0%)
#    진행 상황: 7750 / 25690 미처리 항목 완료 | 총 15560개 (60.4%)
#    진행 상황: 7800 / 25690 미처리 항목 완료 | 총 15660개 (60.8%)
#    진행 상황: 7850 / 25690 미처리 항목 완료 | 총 15760개 (61.2%)
#    진행 상황: 7900 / 25690 미처리 항목 완료 | 총 15860개 (61.6%)
#    진행 상황: 7950 / 25690 미처리 항목 완료 | 총 15960개 (62.0%)
#    진행 상황: 8000 / 25690 미처리 항목 완료 | 총 16060개 (62.4%)
#    진행 상황: 8050 / 25690 미처리 항목 완료 | 총 16160개 (62.8%)
#    진행 상황: 8100 / 25690 미처리 항목 완료 | 총 16260개 (63.1%)
#    진행 상황: 8150 / 25690 미처리 항목 완료 | 총 16360개 (63.5%)
#    진행 상황: 8200 / 25690 미처리 항목 완료 | 총 16460개 (63.9%)
#    진행 상황: 8250 / 25690 미처리 항목 완료 | 총 16560개 (64.3%)
#    진행 상황: 8300 / 25690 미처리 항목 완료 | 총 16660개 (64.7%)
#    진행 상황: 8350 / 25690 미처리 항목 완료 | 총 16760개 (65.1%)
#    진행 상황: 8400 / 25690 미처리 항목 완료 | 총 16860개 (65.5%)
#    진행 상황: 8450 / 25690 미처리 항목 완료 | 총 16960개 (65.9%)
#    진행 상황: 8500 / 25690 미처리 항목 완료 | 총 17060개 (66.3%)
#    진행 상황: 8550 / 25690 미처리 항목 완료 | 총 17160개 (66.6%)
#    진행 상황: 8600 / 25690 미처리 항목 완료 | 총 17260개 (67.0%)
#    진행 상황: 8650 / 25690 미처리 항목 완료 | 총 17360개 (67.4%)
#    진행 상황: 8700 / 25690 미처리 항목 완료 | 총 17460개 (67.8%)
#    진행 상황: 8750 / 25690 미처리 항목 완료 | 총 17560개 (68.2%)
#    진행 상황: 8800 / 25690 미처리 항목 완료 | 총 17660개 (68.6%)
#    진행 상황: 8850 / 25690 미처리 항목 완료 | 총 17760개 (69.0%)
#    진행 상황: 8900 / 25690 미처리 항목 완료 | 총 17860개 (69.4%)
#    진행 상황: 8950 / 25690 미처리 항목 완료 | 총 17960개 (69.7%)
#    진행 상황: 9000 / 25690 미처리 항목 완료 | 총 18060개 (70.1%)
#    진행 상황: 9050 / 25690 미처리 항목 완료 | 총 18160개 (70.5%)
#    진행 상황: 9100 / 25690 미처리 항목 완료 | 총 18260개 (70.9%)
#    진행 상황: 9150 / 25690 미처리 항목 완료 | 총 18360개 (71.3%)
#    진행 상황: 9200 / 25690 미처리 항목 완료 | 총 18460개 (71.7%)
#    진행 상황: 9250 / 25690 미처리 항목 완료 | 총 18560개 (72.1%)
#    진행 상황: 9300 / 25690 미처리 항목 완료 | 총 18660개 (72.5%)
#    진행 상황: 9350 / 25690 미처리 항목 완료 | 총 18760개 (72.9%)
#    진행 상황: 9400 / 25690 미처리 항목 완료 | 총 18860개 (73.2%)
#    진행 상황: 9450 / 25690 미처리 항목 완료 | 총 18960개 (73.6%)
#    진행 상황: 9500 / 25690 미처리 항목 완료 | 총 19060개 (74.0%)
#    진행 상황: 9550 / 25690 미처리 항목 완료 | 총 19160개 (74.4%)
#    진행 상황: 9600 / 25690 미처리 항목 완료 | 총 19260개 (74.8%)
#    진행 상황: 9650 / 25690 미처리 항목 완료 | 총 19360개 (75.2%)
#    진행 상황: 9700 / 25690 미처리 항목 완료 | 총 19460개 (75.6%)
#    진행 상황: 9750 / 25690 미처리 항목 완료 | 총 19560개 (76.0%)
#    진행 상황: 9800 / 25690 미처리 항목 완료 | 총 19660개 (76.3%)
#    진행 상황: 9850 / 25690 미처리 항목 완료 | 총 19760개 (76.7%)
#    진행 상황: 9900 / 25690 미처리 항목 완료 | 총 19860개 (77.1%)
#    진행 상황: 9950 / 25690 미처리 항목 완료 | 총 19960개 (77.5%)
#    진행 상황: 10000 / 25690 미처리 항목 완료 | 총 20060개 (77.9%)
#    진행 상황: 10050 / 25690 미처리 항목 완료 | 총 20160개 (78.3%)
#    진행 상황: 10100 / 25690 미처리 항목 완료 | 총 20260개 (78.7%)
#    진행 상황: 10150 / 25690 미처리 항목 완료 | 총 20360개 (79.1%)
#    진행 상황: 10200 / 25690 미처리 항목 완료 | 총 20460개 (79.5%)
#    진행 상황: 10250 / 25690 미처리 항목 완료 | 총 20560개 (79.8%)
#    진행 상황: 10300 / 25690 미처리 항목 완료 | 총 20660개 (80.2%)
#    진행 상황: 10350 / 25690 미처리 항목 완료 | 총 20760개 (80.6%)
#    진행 상황: 10400 / 25690 미처리 항목 완료 | 총 20860개 (81.0%)
#    진행 상황: 10450 / 25690 미처리 항목 완료 | 총 20960개 (81.4%)
#    진행 상황: 10500 / 25690 미처리 항목 완료 | 총 21060개 (81.8%)
#    진행 상황: 10550 / 25690 미처리 항목 완료 | 총 21160개 (82.2%)
#    진행 상황: 10600 / 25690 미처리 항목 완료 | 총 21260개 (82.6%)
#    진행 상황: 10650 / 25690 미처리 항목 완료 | 총 21360개 (83.0%)
#    진행 상황: 10700 / 25690 미처리 항목 완료 | 총 21460개 (83.3%)
#    진행 상황: 10750 / 25690 미처리 항목 완료 | 총 21560개 (83.7%)
#    진행 상황: 10800 / 25690 미처리 항목 완료 | 총 21660개 (84.1%)
#    진행 상황: 10850 / 25690 미처리 항목 완료 | 총 21760개 (84.5%)
#    진행 상황: 10900 / 25690 미처리 항목 완료 | 총 21860개 (84.9%)
#    진행 상황: 10950 / 25690 미처리 항목 완료 | 총 21960개 (85.3%)
#    진행 상황: 11000 / 25690 미처리 항목 완료 | 총 22060개 (85.7%)
#    진행 상황: 11050 / 25690 미처리 항목 완료 | 총 22160개 (86.1%)
#    진행 상황: 11100 / 25690 미처리 항목 완료 | 총 22260개 (86.4%)
#    진행 상황: 11150 / 25690 미처리 항목 완료 | 총 22360개 (86.8%)
#    진행 상황: 11200 / 25690 미처리 항목 완료 | 총 22460개 (87.2%)
#    진행 상황: 11250 / 25690 미처리 항목 완료 | 총 22560개 (87.6%)
#    진행 상황: 11300 / 25690 미처리 항목 완료 | 총 22660개 (88.0%)
#    진행 상황: 11350 / 25690 미처리 항목 완료 | 총 22760개 (88.4%)
#    진행 상황: 11400 / 25690 미처리 항목 완료 | 총 22860개 (88.8%)
#    진행 상황: 11450 / 25690 미처리 항목 완료 | 총 22960개 (89.2%)
#    진행 상황: 11500 / 25690 미처리 항목 완료 | 총 23060개 (89.6%)
#    진행 상황: 11550 / 25690 미처리 항목 완료 | 총 23160개 (89.9%)
#    진행 상황: 11600 / 25690 미처리 항목 완료 | 총 23260개 (90.3%)
#    진행 상황: 11650 / 25690 미처리 항목 완료 | 총 23360개 (90.7%)
#    진행 상황: 11700 / 25690 미처리 항목 완료 | 총 23460개 (91.1%)
#    진행 상황: 11750 / 25690 미처리 항목 완료 | 총 23560개 (91.5%)
#    진행 상황: 11800 / 25690 미처리 항목 완료 | 총 23660개 (91.9%)
#    진행 상황: 11850 / 25690 미처리 항목 완료 | 총 23760개 (92.3%)
#    진행 상황: 11900 / 25690 미처리 항목 완료 | 총 23860개 (92.7%)
#    진행 상황: 11950 / 25690 미처리 항목 완료 | 총 23960개 (93.0%)
#    진행 상황: 12000 / 25690 미처리 항목 완료 | 총 24060개 (93.4%)
#    진행 상황: 12050 / 25690 미처리 항목 완료 | 총 24160개 (93.8%)
#    진행 상황: 12100 / 25690 미처리 항목 완료 | 총 24260개 (94.2%)
#    진행 상황: 12150 / 25690 미처리 항목 완료 | 총 24360개 (94.6%)
#    진행 상황: 12200 / 25690 미처리 항목 완료 | 총 24460개 (95.0%)
#    진행 상황: 12250 / 25690 미처리 항목 완료 | 총 24560개 (95.4%)
#    진행 상황: 12300 / 25690 미처리 항목 완료 | 총 24660개 (95.8%)
#    진행 상황: 12350 / 25690 미처리 항목 완료 | 총 24760개 (96.2%)
#    진행 상황: 12400 / 25690 미처리 항목 완료 | 총 24860개 (96.5%)
#    진행 상황: 12450 / 25690 미처리 항목 완료 | 총 24960개 (96.9%)
#    진행 상황: 12500 / 25690 미처리 항목 완료 | 총 25060개 (97.3%)
#    진행 상황: 12550 / 25690 미처리 항목 완료 | 총 25160개 (97.7%)
#    진행 상황: 12600 / 25690 미처리 항목 완료 | 총 25260개 (98.1%)
#    진행 상황: 12650 / 25690 미처리 항목 완료 | 총 25360개 (98.5%)
#    진행 상황: 12700 / 25690 미처리 항목 완료 | 총 25460개 (98.9%)
#    진행 상황: 12750 / 25690 미처리 항목 완료 | 총 25560개 (99.3%)
#    진행 상황: 12800 / 25690 미처리 항목 완료 | 총 25660개 (99.7%)
#    진행 상황: 12850 / 25690 미처리 항목 완료 | 총 25760개 (100.0%)
#    진행 상황: 12900 / 25690 미처리 항목 완료 | 총 25860개 (100.4%)
#    진행 상황: 12950 / 25690 미처리 항목 완료 | 총 25960개 (100.8%)
#    진행 상황: 13000 / 25690 미처리 항목 완료 | 총 26060개 (101.2%)
#    진행 상황: 13050 / 25690 미처리 항목 완료 | 총 26160개 (101.6%)
#    진행 상황: 13100 / 25690 미처리 항목 완료 | 총 26260개 (102.0%)
#    진행 상황: 13150 / 25690 미처리 항목 완료 | 총 26360개 (102.4%)
#    진행 상황: 13200 / 25690 미처리 항목 완료 | 총 26460개 (102.8%)
#    진행 상황: 13250 / 25690 미처리 항목 완료 | 총 26560개 (103.1%)
#    진행 상황: 13300 / 25690 미처리 항목 완료 | 총 26660개 (103.5%)
#    진행 상황: 13350 / 25690 미처리 항목 완료 | 총 26760개 (103.9%)
#    진행 상황: 13400 / 25690 미처리 항목 완료 | 총 26860개 (104.3%)
#    진행 상황: 13450 / 25690 미처리 항목 완료 | 총 26960개 (104.7%)
#    진행 상황: 13500 / 25690 미처리 항목 완료 | 총 27060개 (105.1%)
#    진행 상황: 13550 / 25690 미처리 항목 완료 | 총 27160개 (105.5%)
#    진행 상황: 13600 / 25690 미처리 항목 완료 | 총 27260개 (105.9%)
#    진행 상황: 13650 / 25690 미처리 항목 완료 | 총 27360개 (106.3%)
#    진행 상황: 13700 / 25690 미처리 항목 완료 | 총 27460개 (106.6%)
#    진행 상황: 13750 / 25690 미처리 항목 완료 | 총 27560개 (107.0%)
#    진행 상황: 13800 / 25690 미처리 항목 완료 | 총 27660개 (107.4%)
#    진행 상황: 13850 / 25690 미처리 항목 완료 | 총 27760개 (107.8%)
#    진행 상황: 13900 / 25690 미처리 항목 완료 | 총 27860개 (108.2%)
#    진행 상황: 13950 / 25690 미처리 항목 완료 | 총 27960개 (108.6%)
#    진행 상황: 14000 / 25690 미처리 항목 완료 | 총 28060개 (109.0%)
#    진행 상황: 14050 / 25690 미처리 항목 완료 | 총 28160개 (109.4%)
#    진행 상황: 14100 / 25690 미처리 항목 완료 | 총 28260개 (109.7%)
#    진행 상황: 14150 / 25690 미처리 항목 완료 | 총 28360개 (110.1%)
#    진행 상황: 14200 / 25690 미처리 항목 완료 | 총 28460개 (110.5%)
#    진행 상황: 14250 / 25690 미처리 항목 완료 | 총 28560개 (110.9%)
#    진행 상황: 14300 / 25690 미처리 항목 완료 | 총 28660개 (111.3%)
#    진행 상황: 14350 / 25690 미처리 항목 완료 | 총 28760개 (111.7%)
#    진행 상황: 14400 / 25690 미처리 항목 완료 | 총 28860개 (112.1%)
#    진행 상황: 14450 / 25690 미처리 항목 완료 | 총 28960개 (112.5%)
#    진행 상황: 14500 / 25690 미처리 항목 완료 | 총 29060개 (112.9%)
#    진행 상황: 14550 / 25690 미처리 항목 완료 | 총 29160개 (113.2%)
#    진행 상황: 14600 / 25690 미처리 항목 완료 | 총 29260개 (113.6%)
#    진행 상황: 14650 / 25690 미처리 항목 완료 | 총 29360개 (114.0%)
#    진행 상황: 14700 / 25690 미처리 항목 완료 | 총 29460개 (114.4%)
#    진행 상황: 14750 / 25690 미처리 항목 완료 | 총 29560개 (114.8%)
#    진행 상황: 14800 / 25690 미처리 항목 완료 | 총 29660개 (115.2%)
#    진행 상황: 14850 / 25690 미처리 항목 완료 | 총 29760개 (115.6%)
#    진행 상황: 14900 / 25690 미처리 항목 완료 | 총 29860개 (116.0%)
#    진행 상황: 14950 / 25690 미처리 항목 완료 | 총 29960개 (116.3%)
#    진행 상황: 15000 / 25690 미처리 항목 완료 | 총 30060개 (116.7%)
#    진행 상황: 15050 / 25690 미처리 항목 완료 | 총 30160개 (117.1%)
#    진행 상황: 15100 / 25690 미처리 항목 완료 | 총 30260개 (117.5%)
#    진행 상황: 15150 / 25690 미처리 항목 완료 | 총 30360개 (117.9%)
#    진행 상황: 15200 / 25690 미처리 항목 완료 | 총 30460개 (118.3%)
#    진행 상황: 15250 / 25690 미처리 항목 완료 | 총 30560개 (118.7%)
#    진행 상황: 15300 / 25690 미처리 항목 완료 | 총 30660개 (119.1%)
#    진행 상황: 15350 / 25690 미처리 항목 완료 | 총 30760개 (119.5%)
#    진행 상황: 15400 / 25690 미처리 항목 완료 | 총 30860개 (119.8%)
#    진행 상황: 15450 / 25690 미처리 항목 완료 | 총 30960개 (120.2%)
#    진행 상황: 15500 / 25690 미처리 항목 완료 | 총 31060개 (120.6%)
#    진행 상황: 15550 / 25690 미처리 항목 완료 | 총 31160개 (121.0%)
#    진행 상황: 15600 / 25690 미처리 항목 완료 | 총 31260개 (121.4%)
#    진행 상황: 15650 / 25690 미처리 항목 완료 | 총 31360개 (121.8%)
#    진행 상황: 15700 / 25690 미처리 항목 완료 | 총 31460개 (122.2%)
#    진행 상황: 15750 / 25690 미처리 항목 완료 | 총 31560개 (122.6%)
#    진행 상황: 15800 / 25690 미처리 항목 완료 | 총 31660개 (123.0%)
#    진행 상황: 15850 / 25690 미처리 항목 완료 | 총 31760개 (123.3%)
#    진행 상황: 15900 / 25690 미처리 항목 완료 | 총 31860개 (123.7%)
#    진행 상황: 15950 / 25690 미처리 항목 완료 | 총 31960개 (124.1%)
#    진행 상황: 16000 / 25690 미처리 항목 완료 | 총 32060개 (124.5%)
#    진행 상황: 16050 / 25690 미처리 항목 완료 | 총 32160개 (124.9%)
#    진행 상황: 16100 / 25690 미처리 항목 완료 | 총 32260개 (125.3%)
#    진행 상황: 16150 / 25690 미처리 항목 완료 | 총 32360개 (125.7%)
#    진행 상황: 16200 / 25690 미처리 항목 완료 | 총 32460개 (126.1%)
#    진행 상황: 16250 / 25690 미처리 항목 완료 | 총 32560개 (126.4%)
#    진행 상황: 16300 / 25690 미처리 항목 완료 | 총 32660개 (126.8%)
#    진행 상황: 16350 / 25690 미처리 항목 완료 | 총 32760개 (127.2%)
#    진행 상황: 16400 / 25690 미처리 항목 완료 | 총 32860개 (127.6%)
#    진행 상황: 16450 / 25690 미처리 항목 완료 | 총 32960개 (128.0%)
#    진행 상황: 16500 / 25690 미처리 항목 완료 | 총 33060개 (128.4%)
#    진행 상황: 16550 / 25690 미처리 항목 완료 | 총 33160개 (128.8%)
#    진행 상황: 16600 / 25690 미처리 항목 완료 | 총 33260개 (129.2%)
#    진행 상황: 16650 / 25690 미처리 항목 완료 | 총 33360개 (129.6%)
#    진행 상황: 16700 / 25690 미처리 항목 완료 | 총 33460개 (129.9%)
#    진행 상황: 16750 / 25690 미처리 항목 완료 | 총 33560개 (130.3%)
#    진행 상황: 16800 / 25690 미처리 항목 완료 | 총 33660개 (130.7%)
#    진행 상황: 16850 / 25690 미처리 항목 완료 | 총 33760개 (131.1%)
#    진행 상황: 16900 / 25690 미처리 항목 완료 | 총 33860개 (131.5%)
#    진행 상황: 16950 / 25690 미처리 항목 완료 | 총 33960개 (131.9%)
#    진행 상황: 17000 / 25690 미처리 항목 완료 | 총 34060개 (132.3%)
#    진행 상황: 17050 / 25690 미처리 항목 완료 | 총 34160개 (132.7%)
#    진행 상황: 17100 / 25690 미처리 항목 완료 | 총 34260개 (133.0%)
#    진행 상황: 17150 / 25690 미처리 항목 완료 | 총 34360개 (133.4%)
#    진행 상황: 17200 / 25690 미처리 항목 완료 | 총 34460개 (133.8%)
#    진행 상황: 17250 / 25690 미처리 항목 완료 | 총 34560개 (134.2%)
#    진행 상황: 17300 / 25690 미처리 항목 완료 | 총 34660개 (134.6%)
#    진행 상황: 17350 / 25690 미처리 항목 완료 | 총 34760개 (135.0%)
#    진행 상황: 17400 / 25690 미처리 항목 완료 | 총 34860개 (135.4%)
#    진행 상황: 17450 / 25690 미처리 항목 완료 | 총 34960개 (135.8%)
#    진행 상황: 17500 / 25690 미처리 항목 완료 | 총 35060개 (136.2%)
#    진행 상황: 17550 / 25690 미처리 항목 완료 | 총 35160개 (136.5%)
#    진행 상황: 17600 / 25690 미처리 항목 완료 | 총 35260개 (136.9%)
#    진행 상황: 17650 / 25690 미처리 항목 완료 | 총 35360개 (137.3%)
#    진행 상황: 17700 / 25690 미처리 항목 완료 | 총 35460개 (137.7%)
#    진행 상황: 17750 / 25690 미처리 항목 완료 | 총 35560개 (138.1%)
#    진행 상황: 17800 / 25690 미처리 항목 완료 | 총 35660개 (138.5%)
#    진행 상황: 17850 / 25690 미처리 항목 완료 | 총 35760개 (138.9%)
#    진행 상황: 17900 / 25690 미처리 항목 완료 | 총 35860개 (139.3%)
#    진행 상황: 17950 / 25690 미처리 항목 완료 | 총 35960개 (139.7%)
#    진행 상황: 18000 / 25690 미처리 항목 완료 | 총 36060개 (140.0%)
#    진행 상황: 18050 / 25690 미처리 항목 완료 | 총 36160개 (140.4%)
#    진행 상황: 18100 / 25690 미처리 항목 완료 | 총 36260개 (140.8%)
#    진행 상황: 18150 / 25690 미처리 항목 완료 | 총 36360개 (141.2%)
#    진행 상황: 18200 / 25690 미처리 항목 완료 | 총 36460개 (141.6%)
#    진행 상황: 18250 / 25690 미처리 항목 완료 | 총 36560개 (142.0%)
#    진행 상황: 18300 / 25690 미처리 항목 완료 | 총 36660개 (142.4%)
#    진행 상황: 18350 / 25690 미처리 항목 완료 | 총 36760개 (142.8%)
#    진행 상황: 18400 / 25690 미처리 항목 완료 | 총 36860개 (143.1%)
#    진행 상황: 18450 / 25690 미처리 항목 완료 | 총 36960개 (143.5%)
#    진행 상황: 18500 / 25690 미처리 항목 완료 | 총 37060개 (143.9%)
#    진행 상황: 18550 / 25690 미처리 항목 완료 | 총 37160개 (144.3%)
#    진행 상황: 18600 / 25690 미처리 항목 완료 | 총 37260개 (144.7%)
#    진행 상황: 18650 / 25690 미처리 항목 완료 | 총 37360개 (145.1%)
#    진행 상황: 18700 / 25690 미처리 항목 완료 | 총 37460개 (145.5%)
#    진행 상황: 18750 / 25690 미처리 항목 완료 | 총 37560개 (145.9%)
#    진행 상황: 18800 / 25690 미처리 항목 완료 | 총 37660개 (146.3%)
#    진행 상황: 18850 / 25690 미처리 항목 완료 | 총 37760개 (146.6%)
#    진행 상황: 18900 / 25690 미처리 항목 완료 | 총 37860개 (147.0%)
#    진행 상황: 18950 / 25690 미처리 항목 완료 | 총 37960개 (147.4%)
#    진행 상황: 19000 / 25690 미처리 항목 완료 | 총 38060개 (147.8%)
#    진행 상황: 19050 / 25690 미처리 항목 완료 | 총 38160개 (148.2%)
#    진행 상황: 19100 / 25690 미처리 항목 완료 | 총 38260개 (148.6%)
#    진행 상황: 19150 / 25690 미처리 항목 완료 | 총 38360개 (149.0%)
#    진행 상황: 19200 / 25690 미처리 항목 완료 | 총 38460개 (149.4%)
#    진행 상황: 19250 / 25690 미처리 항목 완료 | 총 38560개 (149.7%)
#    진행 상황: 19300 / 25690 미처리 항목 완료 | 총 38660개 (150.1%)
#    진행 상황: 19350 / 25690 미처리 항목 완료 | 총 38760개 (150.5%)
#    진행 상황: 19400 / 25690 미처리 항목 완료 | 총 38860개 (150.9%)
#    진행 상황: 19450 / 25690 미처리 항목 완료 | 총 38960개 (151.3%)
#    진행 상황: 19500 / 25690 미처리 항목 완료 | 총 39060개 (151.7%)
#    진행 상황: 19550 / 25690 미처리 항목 완료 | 총 39160개 (152.1%)
#    진행 상황: 19600 / 25690 미처리 항목 완료 | 총 39260개 (152.5%)
#    진행 상황: 19650 / 25690 미처리 항목 완료 | 총 39360개 (152.9%)
#    진행 상황: 19700 / 25690 미처리 항목 완료 | 총 39460개 (153.2%)
#    진행 상황: 19750 / 25690 미처리 항목 완료 | 총 39560개 (153.6%)
#    진행 상황: 19800 / 25690 미처리 항목 완료 | 총 39660개 (154.0%)
#    진행 상황: 19850 / 25690 미처리 항목 완료 | 총 39760개 (154.4%)
#    진행 상황: 19900 / 25690 미처리 항목 완료 | 총 39860개 (154.8%)
#    진행 상황: 19950 / 25690 미처리 항목 완료 | 총 39960개 (155.2%)
#    진행 상황: 20000 / 25690 미처리 항목 완료 | 총 40060개 (155.6%)
#    진행 상황: 20050 / 25690 미처리 항목 완료 | 총 40160개 (156.0%)
#    진행 상황: 20100 / 25690 미처리 항목 완료 | 총 40260개 (156.3%)
#    진행 상황: 20150 / 25690 미처리 항목 완료 | 총 40360개 (156.7%)
#    진행 상황: 20200 / 25690 미처리 항목 완료 | 총 40460개 (157.1%)
#    진행 상황: 20250 / 25690 미처리 항목 완료 | 총 40560개 (157.5%)
#    진행 상황: 20300 / 25690 미처리 항목 완료 | 총 40660개 (157.9%)
#    진행 상황: 20350 / 25690 미처리 항목 완료 | 총 40760개 (158.3%)
#    진행 상황: 20400 / 25690 미처리 항목 완료 | 총 40860개 (158.7%)
#    진행 상황: 20450 / 25690 미처리 항목 완료 | 총 40960개 (159.1%)
#    진행 상황: 20500 / 25690 미처리 항목 완료 | 총 41060개 (159.5%)
#    진행 상황: 20550 / 25690 미처리 항목 완료 | 총 41160개 (159.8%)
#    진행 상황: 20600 / 25690 미처리 항목 완료 | 총 41260개 (160.2%)
#    진행 상황: 20650 / 25690 미처리 항목 완료 | 총 41360개 (160.6%)
#    진행 상황: 20700 / 25690 미처리 항목 완료 | 총 41460개 (161.0%)
#    진행 상황: 20750 / 25690 미처리 항목 완료 | 총 41560개 (161.4%)
#    진행 상황: 20800 / 25690 미처리 항목 완료 | 총 41660개 (161.8%)
#    진행 상황: 20850 / 25690 미처리 항목 완료 | 총 41760개 (162.2%)
#    진행 상황: 20900 / 25690 미처리 항목 완료 | 총 41860개 (162.6%)
#    진행 상황: 20950 / 25690 미처리 항목 완료 | 총 41960개 (163.0%)
#    진행 상황: 21000 / 25690 미처리 항목 완료 | 총 42060개 (163.3%)
#    진행 상황: 21050 / 25690 미처리 항목 완료 | 총 42160개 (163.7%)
#    진행 상황: 21100 / 25690 미처리 항목 완료 | 총 42260개 (164.1%)
#    진행 상황: 21150 / 25690 미처리 항목 완료 | 총 42360개 (164.5%)
#    진행 상황: 21200 / 25690 미처리 항목 완료 | 총 42460개 (164.9%)
#    진행 상황: 21250 / 25690 미처리 항목 완료 | 총 42560개 (165.3%)
#    진행 상황: 21300 / 25690 미처리 항목 완료 | 총 42660개 (165.7%)
#    진행 상황: 21350 / 25690 미처리 항목 완료 | 총 42760개 (166.1%)
#    진행 상황: 21400 / 25690 미처리 항목 완료 | 총 42860개 (166.4%)
#    진행 상황: 21450 / 25690 미처리 항목 완료 | 총 42960개 (166.8%)
#    진행 상황: 21500 / 25690 미처리 항목 완료 | 총 43060개 (167.2%)
#    진행 상황: 21550 / 25690 미처리 항목 완료 | 총 43160개 (167.6%)
#    진행 상황: 21600 / 25690 미처리 항목 완료 | 총 43260개 (168.0%)
#    진행 상황: 21650 / 25690 미처리 항목 완료 | 총 43360개 (168.4%)
#    진행 상황: 21700 / 25690 미처리 항목 완료 | 총 43460개 (168.8%)
#    진행 상황: 21750 / 25690 미처리 항목 완료 | 총 43560개 (169.2%)
#    진행 상황: 21800 / 25690 미처리 항목 완료 | 총 43660개 (169.6%)
#    진행 상황: 21850 / 25690 미처리 항목 완료 | 총 43760개 (169.9%)
#    진행 상황: 21900 / 25690 미처리 항목 완료 | 총 43860개 (170.3%)
#    진행 상황: 21950 / 25690 미처리 항목 완료 | 총 43960개 (170.7%)
#    진행 상황: 22000 / 25690 미처리 항목 완료 | 총 44060개 (171.1%)
#    진행 상황: 22050 / 25690 미처리 항목 완료 | 총 44160개 (171.5%)
#    진행 상황: 22100 / 25690 미처리 항목 완료 | 총 44260개 (171.9%)
#    진행 상황: 22150 / 25690 미처리 항목 완료 | 총 44360개 (172.3%)
#    진행 상황: 22200 / 25690 미처리 항목 완료 | 총 44460개 (172.7%)
#    진행 상황: 22250 / 25690 미처리 항목 완료 | 총 44560개 (173.0%)
#    진행 상황: 22300 / 25690 미처리 항목 완료 | 총 44660개 (173.4%)
#    진행 상황: 22350 / 25690 미처리 항목 완료 | 총 44760개 (173.8%)
#    진행 상황: 22400 / 25690 미처리 항목 완료 | 총 44860개 (174.2%)
#    진행 상황: 22450 / 25690 미처리 항목 완료 | 총 44960개 (174.6%)
#    진행 상황: 22500 / 25690 미처리 항목 완료 | 총 45060개 (175.0%)
#    진행 상황: 22550 / 25690 미처리 항목 완료 | 총 45160개 (175.4%)
#    진행 상황: 22600 / 25690 미처리 항목 완료 | 총 45260개 (175.8%)
#    진행 상황: 22650 / 25690 미처리 항목 완료 | 총 45360개 (176.2%)
#    진행 상황: 22700 / 25690 미처리 항목 완료 | 총 45460개 (176.5%)
#    진행 상황: 22750 / 25690 미처리 항목 완료 | 총 45560개 (176.9%)
#    진행 상황: 22800 / 25690 미처리 항목 완료 | 총 45660개 (177.3%)
#    진행 상황: 22850 / 25690 미처리 항목 완료 | 총 45760개 (177.7%)
#    진행 상황: 22900 / 25690 미처리 항목 완료 | 총 45860개 (178.1%)
#    진행 상황: 22950 / 25690 미처리 항목 완료 | 총 45960개 (178.5%)
#    진행 상황: 23000 / 25690 미처리 항목 완료 | 총 46060개 (178.9%)
#    진행 상황: 23050 / 25690 미처리 항목 완료 | 총 46160개 (179.3%)
#    진행 상황: 23100 / 25690 미처리 항목 완료 | 총 46260개 (179.7%)
#    진행 상황: 23150 / 25690 미처리 항목 완료 | 총 46360개 (180.0%)
#    진행 상황: 23200 / 25690 미처리 항목 완료 | 총 46460개 (180.4%)
#    진행 상황: 23250 / 25690 미처리 항목 완료 | 총 46560개 (180.8%)
#    진행 상황: 23300 / 25690 미처리 항목 완료 | 총 46660개 (181.2%)
#    진행 상황: 23350 / 25690 미처리 항목 완료 | 총 46760개 (181.6%)
#    진행 상황: 23400 / 25690 미처리 항목 완료 | 총 46860개 (182.0%)
#    진행 상황: 23450 / 25690 미처리 항목 완료 | 총 46960개 (182.4%)
#    진행 상황: 23500 / 25690 미처리 항목 완료 | 총 47060개 (182.8%)
#    진행 상황: 23550 / 25690 미처리 항목 완료 | 총 47160개 (183.1%)
#    진행 상황: 23600 / 25690 미처리 항목 완료 | 총 47260개 (183.5%)
#    진행 상황: 23650 / 25690 미처리 항목 완료 | 총 47360개 (183.9%)
#    진행 상황: 23700 / 25690 미처리 항목 완료 | 총 47460개 (184.3%)
#    진행 상황: 23750 / 25690 미처리 항목 완료 | 총 47560개 (184.7%)
#    진행 상황: 23800 / 25690 미처리 항목 완료 | 총 47660개 (185.1%)
#    진행 상황: 23850 / 25690 미처리 항목 완료 | 총 47760개 (185.5%)
#    진행 상황: 23900 / 25690 미처리 항목 완료 | 총 47860개 (185.9%)
#    진행 상황: 23950 / 25690 미처리 항목 완료 | 총 47960개 (186.3%)
#    진행 상황: 24000 / 25690 미처리 항목 완료 | 총 48060개 (186.6%)
#    진행 상황: 24050 / 25690 미처리 항목 완료 | 총 48160개 (187.0%)
#    진행 상황: 24100 / 25690 미처리 항목 완료 | 총 48260개 (187.4%)
#    진행 상황: 24150 / 25690 미처리 항목 완료 | 총 48360개 (187.8%)
#    진행 상황: 24200 / 25690 미처리 항목 완료 | 총 48460개 (188.2%)
#    진행 상황: 24250 / 25690 미처리 항목 완료 | 총 48560개 (188.6%)
#    진행 상황: 24300 / 25690 미처리 항목 완료 | 총 48660개 (189.0%)
#    진행 상황: 24350 / 25690 미처리 항목 완료 | 총 48760개 (189.4%)
#    진행 상황: 24400 / 25690 미처리 항목 완료 | 총 48860개 (189.7%)
#    진행 상황: 24450 / 25690 미처리 항목 완료 | 총 48960개 (190.1%)
#    진행 상황: 24500 / 25690 미처리 항목 완료 | 총 49060개 (190.5%)
#    진행 상황: 24550 / 25690 미처리 항목 완료 | 총 49160개 (190.9%)
#    진행 상황: 24600 / 25690 미처리 항목 완료 | 총 49260개 (191.3%)
#    진행 상황: 24650 / 25690 미처리 항목 완료 | 총 49360개 (191.7%)
#    진행 상황: 24700 / 25690 미처리 항목 완료 | 총 49460개 (192.1%)
#    진행 상황: 24750 / 25690 미처리 항목 완료 | 총 49560개 (192.5%)
#    진행 상황: 24800 / 25690 미처리 항목 완료 | 총 49660개 (192.9%)
#    진행 상황: 24850 / 25690 미처리 항목 완료 | 총 49760개 (193.2%)
#    진행 상황: 24900 / 25690 미처리 항목 완료 | 총 49860개 (193.6%)
#    진행 상황: 24950 / 25690 미처리 항목 완료 | 총 49960개 (194.0%)
#    진행 상황: 25000 / 25690 미처리 항목 완료 | 총 50060개 (194.4%)
#    진행 상황: 25050 / 25690 미처리 항목 완료 | 총 50160개 (194.8%)
#    진행 상황: 25100 / 25690 미처리 항목 완료 | 총 50260개 (195.2%)
#    진행 상황: 25150 / 25690 미처리 항목 완료 | 총 50360개 (195.6%)
#    진행 상황: 25200 / 25690 미처리 항목 완료 | 총 50460개 (196.0%)
#    진행 상황: 25250 / 25690 미처리 항목 완료 | 총 50560개 (196.3%)
#    진행 상황: 25300 / 25690 미처리 항목 완료 | 총 50660개 (196.7%)
#    진행 상황: 25350 / 25690 미처리 항목 완료 | 총 50760개 (197.1%)
#    진행 상황: 25400 / 25690 미처리 항목 완료 | 총 50860개 (197.5%)
#    진행 상황: 25450 / 25690 미처리 항목 완료 | 총 50960개 (197.9%)
#    진행 상황: 25500 / 25690 미처리 항목 완료 | 총 51060개 (198.3%)
#    진행 상황: 25550 / 25690 미처리 항목 완료 | 총 51160개 (198.7%)
#    진행 상황: 25600 / 25690 미처리 항목 완료 | 총 51260개 (199.1%)
#    진행 상황: 25650 / 25690 미처리 항목 완료 | 총 51360개 (199.5%)
#    진행 상황: 25690 / 25690 미처리 항목 완료 | 총 51440개 (199.8%)
#
# ==================================================
# 🎉 작업 완료!
# 총 소요 시간: 63659.02초
# 최종 데이터 파일: coos_ingredient_database.csv
# 총 25750개 성분 저장 완료.
# ==================================================
